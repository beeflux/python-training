# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session

# %%
# !git clone https://github.com/ghimireadarsh/yolov7.git
# Out:
# Cloning into 'yolov7'...
# remote: Enumerating objects: 630, done.
# remote: Counting objects: 100% (17/17), done.
# remote: Compressing objects: 100% (13/13), done.
# remote: Total 630 (delta 6), reused 8 (delta 4), pack-reused 613
# Receiving objects: 100% (630/630), 42.35 MiB | 30.33 MiB/s, done.
# Resolving deltas: 100% (304/304), done.

# %%
import os
os.chdir('yolov7')

# %%
# Copying previosuly trained weight to home
# !cp /kaggle/input/yolov7-training/yolov7_training.pt yolov7_training.pt

# %%
# !ls
# Out:
# LICENSE.md  deploy     hubconf.py  requirements.txt  train.py
# README.md   detect.py  inference   scripts	     train_aux.py
# cfg	    export.py  models	   test.py	     utils
# data	    figure     paper	   tools	     yolov7_training.pt

# %%
# !ls /kaggle/input/bleed-data/bleed
# Out:
# images	labels	train.txt  val.txt

# %%
# Copying data to home folder
# !cp -r /kaggle/input/bleed-data/bleed bleed/

# %%
# !ls bleed
# Out:
# bleed  images  labels  train.txt  val.txt

# %%
os.listdir()
# Out:
# ['figure',
#  'cfg',
#  'hubconf.py',
#  'utils',
#  'LICENSE.md',
#  'scripts',
#  'inference',
#  'train_aux.py',
#  '.git',
#  'README.md',
#  'bleed',
#  'deploy',
#  'test.py',
#  'yolov7_training.pt',
#  'train.py',
#  'requirements.txt',
#  'tools',
#  '.gitignore',
#  'paper',
#  'data',
#  'models',
#  'detect.py',
#  'export.py']

# %%
# !pip install -r requirements.txt

# %%
# !pip uninstall wandb -y
# Out:
# Found existing installation: wandb 0.15.9
# Uninstalling wandb-0.15.9:
#   Successfully uninstalled wandb-0.15.9

# %%
# !python train.py --workers 8 --device 0 --batch-size 16 --epochs 300 --data data/custom.yaml --img 640 640 --cfg cfg/training/yolov7-custom.yaml --weights 'yolov7_training.pt' --name yolov7-custom --hyp data/hyp.scratch.custom.yaml
# Out:
# /opt/conda/lib/python3.10/site-packages/scipy/__init__.py:146: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.23.5
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"
# wandb: Install Weights & Biases for YOLOR logging with 'pip install wandb' (recommended)
# /opt/conda/lib/python3.10/site-packages/torch/functional.py:504: UserWarning: torch.meshgrid: in an upcoming release, it will be required to pass the indexing argument. (Triggered internally at /usr/local/src/pytorch/aten/src/ATen/native/TensorShape.cpp:3483.)
#   return _VF.meshgrid(tensors, **kwargs)  # type: ignore[attr-defined]
# train: Scanning 'bleed/train' images and labels... 2094 found, 0 missing, 1046 e
# val: Scanning 'bleed/val' images and labels... 524 found, 0 missing, 263 empty,
#
# autoanchor: Analyzing anchors... anchors/target = 4.02, Best Possible Recall (BPR) = 0.9940
# ...
